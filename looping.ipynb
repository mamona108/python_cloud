# %%
num = 1 #counter variable initilized with 10
while num < 10:
    print ("loop executing time:")

# %%
counter = 0
while counter < 5:
    print("loop count",counter)
    counter = counter + 1
# Out:
# loop count 0
# loop count 1
# loop count 2
# loop count 3
# loop count 4

# %%
counter = 1
while counter <=5:
    print("loop count",counter)
    counter = counter + 1
# Out:
# loop count 1
# loop count 2
# loop count 3
# loop count 4
# loop count 5

# %%
counter = 5
while counter < 10:
    print("loop count",counter)
    counter = counter + 4
# Out:
# loop count 5
# loop count 9
